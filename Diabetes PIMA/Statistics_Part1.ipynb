# %% [markdown]
# #  Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe (also known as the Pima Indians). In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima Indian heritage.
#
# -----------------
# ## Objective
# -----------------
#
# To analyse different aspects of Diabetes in the Pima Indians tribe.
#
# -------------------------
# ## Feature descriptions
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function that scores the likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome: Class variable (0: a person is not diabetic or 1: a person is diabetic)

# %% [markdown]
# ## Import the necessary libraries

# %%
# Import libraries for data manipulation
import pandas as pd
import numpy as np

# Import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.gofplots import ProbPlot

# Import libraries for building linear regression model using statsmodel
from statsmodels.formula.api import ols
import statsmodels.api as sm

import scipy.stats as stats
from scipy.stats import levene, ttest_ind, f_oneway, kruskal, shapiro, kstest
from scipy.stats import chi2_contingency

# Importing Linear Regression from sklearn
from sklearn.linear_model import LinearRegression

# Import library for preparing data
from sklearn.model_selection import train_test_split

# Import library for data preprocessing
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load dataset

# %%
pima = pd.read_csv("./diabetes.csv")
pima.shape
# Out:
# (768, 9)

# %% [markdown]
# ## **Statistical Tests - Continuous Variables**

# %% [markdown]
# ### T - Test

# %%
# Separate data into diabetic and non-diabetic groups
diabetic = pima[pima['Outcome'] == 1]
non_diabetic = pima[pima['Outcome'] == 0]

# Perform independent t-tests between numerical columns
numerical_columns = pima.columns

for col in numerical_columns:
    if col != "Outcome":
        t_stat, p_val = stats.ttest_ind(diabetic[col], non_diabetic[col])
        print(f"Independent t-test for {col}:")
        print("t-statistic:", t_stat)
        print("p-value:", p_val)
        if p_val < 0.05:
            print("The difference in {col} between the two groups is statistically significant.")
        else:
            print("The difference in means is not statistically significant")
        print()
# Out:
# Independent t-test for Pregnancies:
# t-statistic: 6.298430550035151
# p-value: 5.065127298053476e-10
# The difference in {col} between the two groups is statistically significant.
#
# Independent t-test for Glucose:
# t-statistic: 15.67806773326978
# p-value: 2.97341391544088e-48
# The difference in {col} between the two groups is statistically significant.
#
# Independent t-test for BloodPressure:
# t-statistic: 4.5689706614887955
# p-value: 5.711009916900583e-06
# The difference in {col} between the two groups is statistically significant.
#
# Independent t-test for SkinThickness:
# t-statistic: 4.82826557728321
# p-value: 1.6631333908835786e-06
# The difference in {col} between the two groups is statistically significant.
#
# Independent t-test for Insulin:
# t-statistic: 5.026611354340738
# p-value: 6.219870924284867e-07
# The difference in {col} between the two groups is statistically significant.
#
# Independent t-test for BMI:
# t-statistic: 9.09702964503362
# p-value: 7.868367931282461e-19
# The difference in {col} between the two groups is statistically significant.
#
# Independent t-test for DiabetesPedigreeFunction:
# t-statistic: 4.88582646072744
# p-value: 1.254607010148809e-06
# The difference in {col} between the two groups is statistically significant.
#
# Independent t-test for Age:
# t-statistic: 6.792688071649956
# p-value: 2.2099754606654358e-11
# The difference in {col} between the two groups is statistically significant.

# %% [markdown]
# ## Relationship of Continuous variables

# %% [markdown]
# ### Pearson Correlation

# %%
for col1 in numerical_columns:
    for col2 in numerical_columns:
        if col1 != col2:
            correlation_coefficient, p_val = stats.pearsonr(pima[col1], pima[col2])
            print(f"Correlation between {col1} and {col2}:")
            print("Correlation coefficient:", correlation_coefficient)
            print("p-value:", p_val)
            if p_val < 0.05:
                print("The correlation is statistically significant at the 5% level.")
            else:
                print("The correlation is not statistically significant at the 5% level.")
            print()
# Out:
# Correlation between Pregnancies and Glucose:
# Correlation coefficient: 0.12802224682727548
# p-value: 0.0003755097066736405
# The correlation is statistically significant at the 5% level.
#
# Correlation between Pregnancies and BloodPressure:
# Correlation coefficient: 0.20898725849828428
# p-value: 5.009006407843621e-09
# The correlation is statistically significant at the 5% level.
#
# Correlation between Pregnancies and SkinThickness:
# Correlation coefficient: 0.009393145275494907
# p-value: 0.7949469195138572
# The correlation is not statistically significant at the 5% level.
#
# Correlation between Pregnancies and Insulin:
# Correlation coefficient: -0.01878025894733311
# p-value: 0.6033062142356396
# The correlation is not statistically significant at the 5% level.
#
# Correlation between Pregnancies and BMI:
# Correlation coefficient: 0.021545924770438516
# p-value: 0.5510450832855005
# The correlation is not statistically significant at the 5% level.
#
# Correlation between Pregnancies and DiabetesPedigreeFunction:
# Correlation coefficient: -0.033522672962613104
# p-value: 0.35353460198769926
# The correlation is not statistically significant at the 5% level.
#
# Correlation between Pregnancies and Age:
# Correlation coefficient: 0.5443412284023394
# p-value: 1.8628128328629845e-60
# The correlation is statistically significant at the 5% level.
#
# Correlation between Pregnancies and Outcome:
# Correlation coefficient: 0.22189815303398652
# p-value: 5.065127298053978e-10
# The correlation is statistically significant at the 5% level.
#
# Correlation between Glucose and Pregnancies:
# Correlation coefficient: 0.12802224682727548
# p-value: 0.0003755097066736405
# The correlation is statistically significant at the 5% level.
#
# Correlation between Glucose and BloodPressure:
# Correlation coefficient: 0.21976513214368737
# p-value: 7.469975794515987e-10
# The correlation is statistically significant at the 5% level.
#
# Correlation between Glucose and SkinThickness:
# Correlation coefficient: 0.15806009267826454
# p-value: 1.0782880835349026e-05
# The correlation is statistically significant at the 5% level.
#
# Correlation between Glucose and Insulin:
# Correlation coefficient: 0.39613656291923105
# p-value: 2.9226278845190705e-30
# The correlation is statistically significant at the 5% level.
#
# Correlation between Glucose and BMI:
# Correlation coefficient: 0.23146374757076565
# p-value: 8.446218854467246e-11
# The correlation is statistically significant at the 5% level.
#
# Correlation between Glucose and DiabetesPedigreeFunction:
# Correlation coefficient: 0.13715830948763758
# p-value: 0.00013735398706801082
# The correlation is statistically significant at the 5% level.
#
# Correlation between Glucose and Age:
# Correlation coefficient: 0.2666734341141117
# p-value: 5.702751168792871e-14
# The correlation is statistically significant at the 5% level.
#
# Correlation between Glucose and Outcome:
# Correlation coefficient: 0.4928841027488203
# p-value: 2.973413915441618e-48
# The correlation is statistically significant at the 5% level.
#
# Correlation between BloodPressure and Pregnancies:
# Correlation coefficient: 0.20898725849828428
# p-value: 5.009006407843621e-09
# The correlation is statistically significant at the 5% level.
#
# Correlation between BloodPressure and Glucose:
# Correlation coefficient: 0.21976513214368737
# p-value: 7.469975794515987e-10
# The correlation is statistically significant at the 5% level.
#
# Correlation between BloodPressure and SkinThickness:
# Correlation coefficient: 0.13040319235855846
# p-value: 0.0002907152983820126
# The correlation is statistically significant at the 5% level.
#
# Correlation between BloodPressure and Insulin:
# Correlation coefficient: 0.010491596974244326
# p-value: 0.7715973947022983
# The correlation is not statistically significant at the 5% level.
#
# Correlation between BloodPressure and BMI:
# Correlation coefficient: 0.281221732146063
# p-value: 1.9964069303749974e-15
# The correlation is statistically significant at the 5% level.
#
# Correlation between BloodPressure and DiabetesPedigreeFunction:
# Correlation coefficient: 0.0004711247603813029
# p-value: 0.9895999276468882
# The correlation is not statistically significant at the 5% level.
#
# Correlation between BloodPressure and Age:
# Correlation coefficient: 0.32679130299835835
# p-value: 1.4307035105877433e-20
# The correlation is statistically significant at the 5% level.
#
# Correlation between BloodPressure and Outcome:
# Correlation coefficient: 0.1628790994986184
# p-value: 5.7110099169010025e-06
# The correlation is statistically significant at the 5% level.
#
# Correlation between SkinThickness and Pregnancies:
# Correlation coefficient: 0.009393145275494907
# p-value: 0.7949469195138572
# The correlation is not statistically significant at the 5% level.
#
# Correlation between SkinThickness and Glucose:
# Correlation coefficient: 0.15806009267826454
# p-value: 1.0782880835349026e-05
# The correlation is statistically significant at the 5% level.
#
# Correlation between SkinThickness and BloodPressure:
# Correlation coefficient: 0.13040319235855846
# p-value: 0.0002907152983820126
# The correlation is statistically significant at the 5% level.
#
# Correlation between SkinThickness and Insulin:
# Correlation coefficient: 0.24541049811405535
# p-value: 5.3615615141258616e-12
# The correlation is statistically significant at the 5% level.
#
# Correlation between SkinThickness and BMI:
# Correlation coefficient: 0.5325519059740897
# p-value: 1.7939631355665143e-57
# The correlation is statistically significant at the 5% level.
#
# Correlation between SkinThickness and DiabetesPedigreeFunction:
# Correlation coefficient: 0.15719607386978937
# p-value: 1.2060764901789034e-05
# The correlation is statistically significant at the 5% level.
#
# Correlation between SkinThickness and Age:
# Correlation coefficient: 0.020582296763853723
# p-value: 0.5690001810323052
# The correlation is not statistically significant at the 5% level.
#
# Correlation between SkinThickness and Outcome:
# Correlation coefficient: 0.171856814176564
# p-value: 1.663133390883656e-06
# The correlation is statistically significant at the 5% level.
#
# Correlation between Insulin and Pregnancies:
# Correlation coefficient: -0.01878025894733311
# p-value: 0.6033062142356396
# The correlation is not statistically significant at the 5% level.
#
# Correlation between Insulin and Glucose:
# Correlation coefficient: 0.39613656291923105
# p-value: 2.9226278845190705e-30
# The correlation is statistically significant at the 5% level.
#
# Correlation between Insulin and BloodPressure:
# Correlation coefficient: 0.010491596974244326
# p-value: 0.7715973947022983
# The correlation is not statistically significant at the 5% level.
#
# Correlation between Insulin and SkinThickness:
# Correlation coefficient: 0.24541049811405535
# p-value: 5.3615615141258616e-12
# The correlation is statistically significant at the 5% level.
#
# Correlation between Insulin and BMI:
# Correlation coefficient: 0.18991937956800525
# p-value: 1.1393719284235992e-07
# The correlation is statistically significant at the 5% level.
#
# Correlation between Insulin and DiabetesPedigreeFunction:
# Correlation coefficient: 0.15824254888609465
# p-value: 1.053005082817569e-05
# The correlation is statistically significant at the 5% level.
#
# Correlation between Insulin and Age:
# Correlation coefficient: 0.03767576404195533
# p-value: 0.2970543747700807
# The correlation is not statistically significant at the 5% level.
#
# Correlation between Insulin and Outcome:
# Correlation coefficient: 0.17869558803050806
# p-value: 6.219870924285291e-07
# The correlation is statistically significant at the 5% level.
#
# Correlation between BMI and Pregnancies:
# Correlation coefficient: 0.021545924770438516
# p-value: 0.5510450832855005
# The correlation is not statistically significant at the 5% level.
#
# Correlation between BMI and Glucose:
# Correlation coefficient: 0.23146374757076565
# p-value: 8.446218854467246e-11
# The correlation is statistically significant at the 5% level.
#
# Correlation between BMI and BloodPressure:
# Correlation coefficient: 0.281221732146063
# p-value: 1.9964069303749974e-15
# The correlation is statistically significant at the 5% level.
#
# Correlation between BMI and SkinThickness:
# Correlation coefficient: 0.5325519059740897
# p-value: 1.7939631355665143e-57
# The correlation is statistically significant at the 5% level.
#
# Correlation between BMI and Insulin:
# Correlation coefficient: 0.18991937956800525
# p-value: 1.1393719284235992e-07
# The correlation is statistically significant at the 5% level.
#
# Correlation between BMI and DiabetesPedigreeFunction:
# Correlation coefficient: 0.15350799759376843
# p-value: 1.9324366889007487e-05
# The correlation is statistically significant at the 5% level.
#
# Correlation between BMI and Age:
# Correlation coefficient: 0.025748112653889536
# p-value: 0.4761499467525475
# The correlation is not statistically significant at the 5% level.
#
# Correlation between BMI and Outcome:
# Correlation coefficient: 0.3122541323335877
# p-value: 7.86836793128411e-19
# The correlation is statistically significant at the 5% level.
#
# Correlation between DiabetesPedigreeFunction and Pregnancies:
# Correlation coefficient: -0.033522672962613104
# p-value: 0.35353460198769926
# The correlation is not statistically significant at the 5% level.
#
# Correlation between DiabetesPedigreeFunction and Glucose:
# Correlation coefficient: 0.13715830948763758
# p-value: 0.00013735398706801082
# The correlation is statistically significant at the 5% level.
#
# Correlation between DiabetesPedigreeFunction and BloodPressure:
# Correlation coefficient: 0.0004711247603813029
# p-value: 0.9895999276468882
# The correlation is not statistically significant at the 5% level.
#
# Correlation between DiabetesPedigreeFunction and SkinThickness:
# Correlation coefficient: 0.15719607386978937
# p-value: 1.2060764901789034e-05
# The correlation is statistically significant at the 5% level.
#
# Correlation between DiabetesPedigreeFunction and Insulin:
# Correlation coefficient: 0.15824254888609465
# p-value: 1.053005082817569e-05
# The correlation is statistically significant at the 5% level.
#
# Correlation between DiabetesPedigreeFunction and BMI:
# Correlation coefficient: 0.15350799759376843
# p-value: 1.9324366889007487e-05
# The correlation is statistically significant at the 5% level.
#
# Correlation between DiabetesPedigreeFunction and Age:
# Correlation coefficient: 0.03356131243480552
# p-value: 0.3529797336668881
# The correlation is not statistically significant at the 5% level.
#
# Correlation between DiabetesPedigreeFunction and Outcome:
# Correlation coefficient: 0.1738440656529598
# p-value: 1.2546070101488676e-06
# The correlation is statistically significant at the 5% level.
#
# Correlation between Age and Pregnancies:
# Correlation coefficient: 0.5443412284023394
# p-value: 1.8628128328629845e-60
# The correlation is statistically significant at the 5% level.
#
# Correlation between Age and Glucose:
# Correlation coefficient: 0.2666734341141117
# p-value: 5.702751168792871e-14
# The correlation is statistically significant at the 5% level.
#
# Correlation between Age and BloodPressure:
# Correlation coefficient: 0.32679130299835835
# p-value: 1.4307035105877433e-20
# The correlation is statistically significant at the 5% level.
#
# Correlation between Age and SkinThickness:
# Correlation coefficient: 0.020582296763853723
# p-value: 0.5690001810323052
# The correlation is not statistically significant at the 5% level.
#
# Correlation between Age and Insulin:
# Correlation coefficient: 0.03767576404195533
# p-value: 0.2970543747700807
# The correlation is not statistically significant at the 5% level.
#
# Correlation between Age and BMI:
# Correlation coefficient: 0.025748112653889536
# p-value: 0.4761499467525475
# The correlation is not statistically significant at the 5% level.
#
# Correlation between Age and DiabetesPedigreeFunction:
# Correlation coefficient: 0.03356131243480552
# p-value: 0.3529797336668881
# The correlation is not statistically significant at the 5% level.
#
# Correlation between Age and Outcome:
# Correlation coefficient: 0.2383559830271976
# p-value: 2.2099754606655505e-11
# The correlation is statistically significant at the 5% level.
#
# Correlation between Outcome and Pregnancies:
# Correlation coefficient: 0.22189815303398652
# p-value: 5.065127298053978e-10
# The correlation is statistically significant at the 5% level.
#
# Correlation between Outcome and Glucose:
# Correlation coefficient: 0.4928841027488203
# p-value: 2.973413915441618e-48
# The correlation is statistically significant at the 5% level.
#
# Correlation between Outcome and BloodPressure:
# Correlation coefficient: 0.1628790994986184
# p-value: 5.7110099169010025e-06
# The correlation is statistically significant at the 5% level.
#
# Correlation between Outcome and SkinThickness:
# Correlation coefficient: 0.171856814176564
# p-value: 1.663133390883656e-06
# The correlation is statistically significant at the 5% level.
#
# Correlation between Outcome and Insulin:
# Correlation coefficient: 0.17869558803050806
# p-value: 6.219870924285291e-07
# The correlation is statistically significant at the 5% level.
#
# Correlation between Outcome and BMI:
# Correlation coefficient: 0.3122541323335877
# p-value: 7.86836793128411e-19
# The correlation is statistically significant at the 5% level.
#
# Correlation between Outcome and DiabetesPedigreeFunction:
# Correlation coefficient: 0.1738440656529598
# p-value: 1.2546070101488676e-06
# The correlation is statistically significant at the 5% level.
#
# Correlation between Outcome and Age:
# Correlation coefficient: 0.2383559830271976
# p-value: 2.2099754606655505e-11
# The correlation is statistically significant at the 5% level.
